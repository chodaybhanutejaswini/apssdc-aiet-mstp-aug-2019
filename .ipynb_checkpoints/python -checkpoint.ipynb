# %% [markdown]
# # markdown introduction

# %% [markdown]
# # bhanu
# ## bhanu
# ### bhanu
# #### bhanu
# ##### bhanu
# ###### bhanu

# %% [markdown]
# **bold**

# %% [markdown]
# *italic*

# %% [markdown]
# <strike>prohibited</strike> <br>
# `bhanu`

# %% [markdown]
# <img src="https://cdn0.iconfinder.com/data/icons/long-shadow-web-icons/512/python-512.png" width="200px" height="200px">

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%HTML
# <iframe width="200" height="200" src="https://www.youtube.com/embed/cpPG0bKHYKc" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="200" height="200" src="https://www.youtube.com/embed/cpPG0bKHYKc" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# * python
# * java
# * r programming
# * script languages
#  - html
#  - tml

# %%
print("hi bhanu")
print("what are you doing ")
# Out:
# hi bhanu
# what are you doing

# %% [markdown]
# # operators

# %% [markdown]
# * arithmetic operators
# * logical operators
# * assignment operators
# * relational operators
# * bit wise operators

# %% [markdown]
# # arithmetic operators

# %%
print(21+12)
# Out:
# 33

# %%
type(1)
# Out:
# int

# %%
type(10/8)
# Out:
# float

# %%
10//3
# Out:
# 3

# %%
10%3
# Out:
# 1

# %%
2**4
# Out:
# 16

# %%
pow(2,4)
# Out:
# 16

# %% [markdown]
# # logical operators

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False or False
# Out:
# False

# %%
not True
# Out:
# False

# %% [markdown]
# # relational operators

# %%
2 == 3
# Out:
# False

# %%
2<7
# Out:
# True

# %%
9==9
# Out:
# True

# %% [markdown]
# # assignment operators

# %%
a=6

# %%
type(a)
# Out:
# int

# %%
type(a)
# Out:
# int

# %%
a=b=c=10

# %%
a,b,c
# Out:
# (10, 10, 10)

# %%
print(a,b,c)
# Out:
# 10 10 10

# %%
a
b
c
# Out:
# 10

# %%
a,b,c=1,2,3

# %%
a,b=b,a

# %%
print(a,b)
# Out:
# 2 1

# %%
a++
# Out:
#   File "<ipython-input-33-c828489c4eb6>", line 1
#     a++
#         ^
# SyntaxError: invalid syntax

# %%
a +=1 # assignment operators

# %%
a+=1
a
# Out:
# 4

# %% [markdown]
# # bitwise operators

# %%
4 & 2
# Out:
# 0

# %%
7 | 2
# Out:
# 7

# %%
8 < 9
# Out:
# True

# %%
2 << 5
# Out:
# 64

# %% [markdown]
# # identity operators( to identify the content)

# %%
2==3
# Out:
# False

# %%
2 is 3
# Out:
# False

# %%
2 is not 3
# Out:
# True

# %% [markdown]
# # membership operators

# %%
"bha" in "bhanu"
# Out:
# True

# %%
"Ap" in "apssdc"
# Out:
# False

# %%
'ap' in "apssdc"
# Out:
# True

# %%
"t" not in "apssdc"
# Out:
# True
